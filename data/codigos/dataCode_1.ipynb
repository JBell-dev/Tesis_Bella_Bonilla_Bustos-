# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
def numerizeYear(df):
  df.reset_index(inplace=True)
  df['Year']=pd.to_numeric(df['Year'])
  df.set_index(['Borough','Year'],inplace=True)
  return df
def boroughSetter(df):
  df.reset_index(inplace=True)
  df['Borough'] = df['Borough'].str.replace(' Of ', ' of ')
  df['Borough'] = df['Borough'].str.replace(' Upon ', ' upon ')
  df['Borough'] = df['Borough'].str.replace(' & ', ' and ')
  df['Borough'] = df['Borough'].str.replace('City of Westminster', 'Westminster')
  
  df.set_index(['Borough','Year'],inplace=True)
  return df

def junter(full,new):
  new=numerizeYear(new)
  new=boroughSetter(new)
  result=pd.concat([full, new],axis=1)
  return result

def checker(df,start,finish):
  print('la lenght es ',len(df))
  for i in np.arange(start,finish+1,1):
    print(len(df.loc[(slice(None),i),:]))
  return None

# %%
df0=pd.read_csv('activenterprisesbyborough.csv')

df1=pd.read_csv('electricityconsumption1.csv',index_col=[0,1],header=[0,1])


#df0=numerizeYear(df0)
#df1=numerizeYear(df1)
#dFull=df1
#dFull
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-964b3a47f0c3> in <module>()
#       6
#       7 #df0=numerizeYear(df0)
# ----> 8 df1=numerizeYear(df1)
#       9 dFull=df1
#      10 dFull
#
# <ipython-input-18-ad4c4f7e12ae> in numerizeYear(df)
#       1 def numerizeYear(df):
#       2   df.reset_index(inplace=True)
# ----> 3   df['Year']=pd.to_numeric(df['Year'])
#       4   df.set_index(['Borough','Year'],inplace=True)
#       5   return df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2903         if is_single_key:
#    2904             if self.columns.nlevels > 1:
# -> 2905                 return self._getitem_multilevel(key)
#    2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2953     def _getitem_multilevel(self, key):
#    2954         # self.columns is a MultiIndex
# -> 2955         loc = self.columns.get_loc(key)
#    2956         if isinstance(loc, (slice, np.ndarray)):
#    2957             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2702
#    2703         if not isinstance(key, tuple):
# -> 2704             loc = self._get_level_indexer(key, level=0)
#    2705             return _maybe_to_slice(loc)
#    2706
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2967         else:
#    2968
# -> 2969             code = self._get_loc_single_level_index(level_index, key)
#    2970
#    2971             if level > 0 or self.lexsort_depth == 0:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2635             return -1
#    2636         else:
# -> 2637             return level_index.get_loc(key)
#    2638
#    2639     def get_loc(self, key, method=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Year'

# %%
#cambiar formato de columnas
df2=pd.read_csv('cob-borough.csv')
display(df2)
df2=numerizeYear(df2)
dFull1=pd.concat([dFull, df2],axis=1)
checker(dFull1,1999,2020)
dFull1
# Out:
#                                         Code  ... Non-European Union
#                           Unnamed: 2_level_1  ...  Rest of the World
#                           Unnamed: 2_level_2  ...            Oceania
# Borough              Year                     ...
# Barking and Dagenham 2004          E09000002  ...                NaN
#                      2005          E09000002  ...                NaN
#                      2006          E09000002  ...                NaN
#                      2007          E09000002  ...                NaN
#                      2008          E09000002  ...                NaN
# ...                                      ...  ...                ...
# Westminster          2014          E09000033  ...                6.0
#                      2015          E09000033  ...                5.0
#                      2016          E09000033  ...                4.0
#                      2017          E09000033  ...                2.0
#                      2018          E09000033  ...                3.0
#
# [495 rows x 22 columns]
# la lenght es  528
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1999
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-6e6829184753> in <module>()
#       4 df2=numerizeYear(df2)
#       5 dFull1=pd.concat([dFull, df2],axis=1)
# ----> 6 checker(dFull1,1999,2020)
#       7 dFull1
#
# <ipython-input-18-ad4c4f7e12ae> in checker(df, start, finish)
#      23   print('la lenght es ',len(df))
#      24   for i in np.arange(start,finish+1,1):
# ---> 25     print(len(df.loc[(slice(None),i),:]))
#      26   return None
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     764         # we may have a nested tuples indexer here
#     765         if self._is_nested_tuple_indexer(tup):
# --> 766             return self._getitem_nested_tuple(tup)
#     767
#     768         # we maybe be using a tuple to represent multiple dimensions here
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     845
#     846             current_ndim = obj.ndim
# --> 847             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     848             axis += 1
#     849
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1101             # nested tuple slicing
#    1102             if is_nested_tuple(key, labels):
# -> 1103                 locs = labels.get_locs(key)
#    1104                 indexer = [slice(None)] * self.ndim
#    1105                 indexer[axis] = locs
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in get_locs(self, seq)
#    3100                 indexer = _update_indexer(
#    3101                     _convert_to_indexer(
# -> 3102                         self.get_loc_level(k, level=i, drop_level=False)[0]
#    3103                     ),
#    3104                     indexer=indexer,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2883                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    2884         else:
# -> 2885             indexer = self._get_level_indexer(key, level=level)
#    2886             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    2887
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2967         else:
#    2968
# -> 2969             code = self._get_loc_single_level_index(level_index, key)
#    2970
#    2971             if level > 0 or self.lexsort_depth == 0:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2635             return -1
#    2636         else:
# -> 2637             return level_index.get_loc(key)
#    2638
#    2639     def get_loc(self, key, method=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 1999

# %%
df3=pd.read_csv('electoral-roll-numbers-borough.csv')
dFull2=junter(dFull1,df3)
checker(dFull2,1999,2020)
dFull2

# %%
url='met-police-recorded-offences-rates-borough.csv'
df4=pd.read_csv(url)
dFull3=junter(dFull2,df4)
checker(dFull3,1999,2020)
dFull3

# %%
url='housing-density-borough.csv'
df5=pd.read_csv(url)
df5=df5.drop(['London','Inner London','Outer London','Greater London'])
dFull4=junter(dFull3,df5)
checker(dFull4,1999,2050)
dFull4

# %%
url='nationality-borough.csv'
df6=pd.read_csv(url)
df6.columns = ['__'.join(col).strip() for col in df6.columns.values]
df6.columns = [f'nationality/{col}' for col in df6.columns.values]

dFull5=junter(dFull4,df6)
checker(dFull5,1999,2050)
dFull5

# %%
url='statutory-homelessness-borough 2017-18 revised.csv'
df7=pd.read_csv(url)


dFull6=junter(dFull5,df7)
checker(dFull6,1999,2050)
dFull6

# %%
url='population-by-religion-borough.csv'
df8=pd.read_csv(url)


dFull7=junter(dFull6,df8)
checker(dFull7,1999,2050)
dFull7

# %%
url='Internal-migration-flows-age-groups-0to15-2002-2016.csv'
df9=pd.read_csv(url)
df9.reset_index(inplace=True)
df9.set_index(['Borough','Year','age-group'],inplace=True)
df9=df9.unstack()
df9.columns = ['/'.join(col).strip() for col in df9.columns.values]
dFull8=junter(dFull7,df9)
checker(dFull8,1999,2050)
dFull8

# %%
url='population-estimates-single-year-age.csv'
df10=pd.read_csv(url)
df10=df10.loc[:,'PERSONS']
df10.columns = [f'age/{col}' for col in df10.columns.values]


dFull9=junter(dFull8,df10)
checker(dFull9,1999,2050)

dFull9

# %%
#dFull9.to_pickle('fullLondon0.pkl')
#dFull9.to_csv('fullLondon0.csv')

# %%
#boroughSetter(df)
def firstFour(cell):
  return cell[0:4]
df0=pd.read_csv('fullLondonV1.csv')
df1=pd.read_csv('UK INDEX PRICES.csv')
df1.reset_index(inplace=True)
df1.set_index(['Borough','Year'],inplace=True)
df1.sort_index(inplace=True)
df1=boroughSetter(df1)
df1=df1.drop(['EAST MIDLANDS','EAST OF ENGLAND','England','Inner London','LONDON','NORTH EAST','NORTH WEST','Outer London','SOUTH EAST','SOUTH WEST','WEST MIDLANDS','YORKS and THE HUMBER'])
df1.reset_index(inplace=True)
df1=df1.rename(columns={'Category':'','Year':'Date'})
df1['Date']=df1['Date'].apply(str)
df1['Year']=df1['Date'].apply(firstFour)
df1['Year']=pd.to_numeric(df1['Year'])
df1['Month']=df1['Date'].apply(lambda cell: cell[5:7])
df1['Month']=pd.to_numeric(df1['Month'])
df1=df1.drop('Date',axis=1)
#df1.to_excel('medio.xlsx')
df2=pd.read_excel('/content/medio.xlsx')
df2=df2.drop('Unnamed: 0',axis=1)
df2.set_index(['Borough','Year','Month'],inplace=True)
df2=df2.unstack()
df2=df2.rename_axis(columns={'Month':''})  
#df2.to_csv('price.csv')
#df2.to_pickle('price.pkl')

# %%
url='/content/price.pkl'
dfv=pd.read_pickle(url)
gf = [f'{col[0]}/{col[1]}' for col in dfv.columns.values]
dfv.columns = [f'{col[0]}/{col[1]}' for col in dfv.columns.values]
acum=junter(df0,dfv)
checker(acum,1999,2020)
#acum.to_csv('fullLondonV2.csv')
#acum.to_pickle('fullLondonV2.pkl')
# Out:
# la lenght es  1848
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %%
def firstFour(cell):
  return cell[0:4]
df0=pd.read_csv('fullLondonV1.csv')
df1=pd.read_csv('avg prices by type.csv')

df1.reset_index(inplace=True)
df1['Date']=df1['Date'].apply(str)
df1['Year']=df1['Date'].apply(firstFour)
df1['Year']=pd.to_numeric(df1['Year'])
df1['Month']=df1['Date'].apply(lambda cell: cell[5:7])
df1['Month']=pd.to_numeric(df1['Month'])
df1.set_index(['Borough','Year'],inplace=True)
df1.sort_index(inplace=True)
df1=boroughSetter(df1)

boroughs=df0.loc[(slice(None),2000),:].reset_index()['Borough'].to_numpy()
df1=df1.loc[boroughs,:]
df1=df1.drop('Date',axis=1)

df1.reset_index(inplace=True)

df1.set_index(['Borough','Year','Month'],inplace=True)
df1=df1.unstack()
df1=df1.rename_axis(columns={'Month':''})  


df1.columns = [f'{col[0]}/{col[1]}' for col in df1.columns.values]
acum=junter(df0,df1)
checker(acum,1995,2020)
#acum.to_csv('fullLondonV3.csv')
#acum.to_pickle('fullLondonV3.pkl')
# Out:
# la lenght es  1848
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
